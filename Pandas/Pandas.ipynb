# %% [markdown]
# # Pandas Tutorial

# %% [markdown]
# ## Loading data into Pandas

# %%
import pandas as pd

# %%
# reading CSV file using pd.read_csv('')
data = pd.read_csv('pokemon_data.csv')

# reading Excel file using pd.read_excel('')
# !pip install openpyxl
# data = pd.read_excel('pokemon_data.xlsx')

# reading txt file using pd.read_csv('') and specify delimeter
# data = pd.read_csv('pokemon_data.txt', delimiter='\t')

print(data)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
#reading the head(from top) of our data 
#initially threr will be 5 rows but we can specify nuumber
print(data.head(6))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
# 5  5             Charmeleon   Fire     NaN  58      64       58       80
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# 5       65     80           1      False

# %%
#reading the tail(from bottom ) of our data
#initially threr will be 5 rows but we can specify nuumber
print(data.tail(10))
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 790  714               Noibat   Flying  Dragon   40      30       35       45
# 791  715              Noivern   Flying  Dragon   85      70       80       97
# 792  716              Xerneas    Fairy     NaN  126     131       95      131
# 793  717              Yveltal     Dark  Flying  126     131       95      131
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 795  719              Diancie     Rock   Fairy   50     100      150      100
# 796  719  DiancieMega Diancie     Rock   Fairy   50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 799  721            Volcanion     Fire   Water   80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 790       40     55           6      False
# ...

# %% [markdown]
# ## Reading Data in Pandas

# %%
# Read Headers
#will print all column names
# print(data.columns) 

# Read specific colummn
print(data[['#', 'Name']][0:10])
# Out:
#    #                       Name
# 0  1                  Bulbasaur
# 1  2                    Ivysaur
# 2  3                   Venusaur
# 3  3      VenusaurMega Venusaur
# 4  4                 Charmander
# 5  5                 Charmeleon
# 6  6                  Charizard
# 7  6  CharizardMega Charizard X
# 8  6  CharizardMega Charizard Y
# 9  7                   Squirtle

# %%
# Read specific rows
# print(data.iloc[0:5])

#reading rows by iterating through them
# for index, row in data.iterrows():
#     print(index, row['Name'])

# Reading specific location
# print(data.iloc[4, 2]) #iloc is number based
print(data.loc[data['HP'] < 10]) #more in filtering and specific rows
# Out:
#        #      Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292  Shedinja    Bug  Ghost   1      90       45       30       30
#
#      Speed  Generation  Legendary
# 316     40           3      False

# %% [markdown]
# ## Sorting/ Describing Data

# %%
# Specifies the min, max, mean etc
data.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
# Sorting through data 
# Note: specify ascending=False if want to sort in descending
data.sort_values(by=['Type 1','Attack'], ascending=[1,1])
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 230  213                Shuckle    Bug    Rock   20      10      230       10
# 14    11                Metapod    Bug     NaN   50      20       55       25
# 179  165                 Ledyba    Bug  Flying   40      20       30       40
# 733  665                 Spewpa    Bug     NaN   45      22       60       27
# 17    14                 Kakuna    Bug  Poison   45      25       50       25
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 107   99                Kingler  Water     NaN   55     130      115       50
# 349  319  SharpedoMega Sharpedo  Water    Dark   70     140       70      110
# 283  260  SwampertMega Swampert  Water  Ground  100     150      110       95
# 422  382    KyogrePrimal Kyogre  Water     NaN  100     150       90      180
# 141  130  GyaradosMega Gyarados  Water    Dark   95     155      109       70
#
# ...

# %% [markdown]
# ## Making changes to our data

# %%
data.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
#Adding a new column total = HP+ Attack+ Defense+ Sp.Atk+ Sp.Def+ Speed
# data['Total'] = data['HP']+ data['Attack']+ data['Defense']+ data['Sp. Def']+ data['Sp. Atk']+ data['Speed']
data['Total'] = data.iloc[:,4:10].sum(axis=1)
# Above statement added a new column 'total'
print(data[['Name','Total']])
# Out:
#                       Name  Total
# 0                Bulbasaur    318
# 1                  Ivysaur    405
# 2                 Venusaur    525
# 3    VenusaurMega Venusaur    625
# 4               Charmander    309
# ..                     ...    ...
# 795                Diancie    600
# 796    DiancieMega Diancie    700
# 797    HoopaHoopa Confined    600
# 798     HoopaHoopa Unbound    680
# 799              Volcanion    600
#
# [800 rows x 2 columns]

# %%
data.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
# Dropping/deleting a column_
data = data.drop(columns=['Legendary'])
data.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Total
# 0       65     45           1    318
# 1       80     60           1    405
# 2      100     80           1    525
# 3      120     80           1    625
# 4       50     65           1    309

# %%
# Moving position of columns
columns = list(data.columns.values)
print(columns)
data = data[columns[0:4] + [columns[-1]] + columns[4:11]]
# print(data.head())
# Out:
# ['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Total']

# %% [markdown]
# ## Saving our data(Exporting it to desired extension)

# %%
# print(data)
data.to_csv('Updated_data.csv', index=False)
# data.to_excel('Updated_data.xlsx', index=False)
# data.to_csv('Updated_data.txt', index=False, sep='\t')

# %% [markdown]
# ## Filtering Data

# %%
data.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation
# 0       65       65     45           1
# 1       80       80     60           1
# 2      100      100     80           1
# 3      122      120     80           1
# 4       60       50     65           1

# %%
# in pandas use '&' for 'and' and '|' for 'or'
# Filtering data 
new_data = data.loc[(data['Type 1'] == 'Grass') & (data['Type 2'] == 'Poison') & (data['Total'] > 500)]
# print(new_data)
# we can export this filtered data eailt using new_data.to_csv('filtered.csv')
# but we notice that the index in file is the old one.So,
new_data = new_data.reset_index(drop=True)
# print(new_data)
new_data.to_csv('filtered.csv')
# Out:
#      #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0    3               Venusaur  Grass  Poison    525  80      82       83
# 1    3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 2  407               Roserade  Grass  Poison    515  60      70       65
#
#    Sp. Atk  Sp. Def  Speed  Generation Flame Thrower
# 0      100      100     80           1           NaN
# 1      122      120     80           1           NaN
# 2      125      105     90           4           NaN

# %%
# Editing names by filtering them
#for eg. here we are going to get entries with 'mega' in name.
mega = data.loc[data['Name'].str.contains('Mega')]
# print(mega)

# %%
# Using regular expressions
import re
# ...................^ means starting with char not in middle or anywhere
mega = mega.loc[data['Name'].str.contains('Char', flags=re.I, regex=True)]
print(mega)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
#
#    Sp. Atk  Sp. Def  Speed  Generation Flame Thrower
# 7      130       85    100           1           NaN
# 8      159      115    100           1           NaN

# %% [markdown]
# ## Conditional Statements

# %%
#Changing Type 1 with 'dragon' to 'flamethrower'
# .loc[rowindexer, columnindexer] = value
mega.loc[mega['Type 2']=='Dragon', 'Type 2'] = 'Flame Thrower'
print(mega)
# Out:
#    #                       Name Type 1         Type 2  Total  HP  Attack  \
# 7  6  CharizardMega Charizard X   Fire  Flame Thrower    634  78     130
# 8  6  CharizardMega Charizard Y   Fire         Flying    634  78     104
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation Flame Thrower
# 7      111      130       85    100           1           NaN
# 8       78      159      115    100           1           NaN

# %%
data.loc[data['Total']> 500, ['Generation']] = ['Leveled UP']
data
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation
# ...

# %% [markdown]
# ## Aggerate Statstics(Groupby)

# %%
data = pd.read_csv('pokemon_data.csv')

data.groupby(['Type 1']).mean().sort_values('Sp. Atk', ascending=False)
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Psychic   380.807018  70.631579   71.456140   67.684211  98.403509  86.280702
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Flying    677.750000  70.750000   78.750000   66.250000  94.250000  72.500000
# Electric  363.500000  59.795455   69.090909   66.295455  90.022727  73.704545
# Fire      327.403846  69.903846   84.769231   67.769231  88.980769  72.211538
# Ghost     486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# Fairy     449.529412  74.117647   61.529412   65.705882  78.529412  84.705882
# Ice       423.541667  72.000000   72.750000   71.416667  77.541667  76.291667
# Grass     344.871429  67.271429   73.214286   70.800000  77.500000  70.428571
# Water     303.089286  72.062500   74.151786   72.946429  74.812500  70.517857
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# ...

# %%
data.groupby(['Type 1']).sum()
# Out:
#               #    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type 1
# Bug       23080  3925    4897     4880     3717     4471   4256         222
# Dark      14302  2071    2740     2177     2314     2155   2361         125
# Dragon    15180  2666    3588     2764     3099     2843   2657         124
# Electric  15994  2631    3040     2917     3961     3243   3718         144
# Fairy      7642  1260    1046     1117     1335     1440    826          70
# Fighting   9824  1886    2613     1780     1434     1747   1784          91
# Fire      17025  3635    4408     3524     4627     3755   3871         167
# Flying     2711   283     315      265      377      290    410          22
# Ghost     15568  2062    2361     2598     2539     2447   2059         134
# Grass     24141  4709    5125     4956     5425     4930   4335         235
# Ground    11401  2361    3064     2715     1807     2008   2045         101
# ...

# %%
data['count']=1
data.groupby(['Type 1', 'Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %% [markdown]
# ## Working with large amounts of data

# %%
# reading data here with 10 rows at a time
for data in pd.read_csv('pokemon_data.csv', chunksize=10):  
    print("----------------------------------")
    print(data)
    break
# Out:
# ----------------------------------
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %%
# this makes a new empty data frame with same name and number of column as specified df
new_data = pd.DataFrame(columns=data.columns)

for df in pd.read_csv('pokemon_data.csv', chunksize=10):
    results = df.groupby(['Type 1']).count()
    new_data = pd.concat([new_data, results])
    print(new_data)
# Out:
#        # Name Type 1 Type 2 HP Attack Defense Sp. Atk Sp. Def Speed  \
# Fire   5    5    NaN      3  5      5       5       5       5     5
# Grass  4    4    NaN      4  4      4       4       4       4     4
# Water  1    1    NaN      0  1      1       1       1       1     1
#
#       Generation Legendary
# Fire           5         5
# Grass          4         4
# Water          1         1
#        # Name Type 1 Type 2 HP Attack Defense Sp. Atk Sp. Def Speed  \
# Fire   5    5    NaN      3  5      5       5       5       5     5
# Grass  4    4    NaN      4  4      4       4       4       4     4
# Water  1    1    NaN      0  1      1       1       1       1     1
# Bug    7    7    NaN      5  7      7       7       7       7     7
# Water  3    3    NaN      0  3      3       3       3       3     3
#
#       Generation Legendary
# Fire           5         5
# Grass          4         4
# Water          1         1
# Bug            7         7
# Water          3         3
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []
